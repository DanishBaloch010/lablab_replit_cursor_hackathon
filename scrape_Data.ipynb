# %% [markdown]
# # fetch mkbhd data

# %%
import pandas as pd
import requests
import yt_dlp
from youtube_transcript_api import YouTubeTranscriptApi
import csv
import os
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv()

# YouTube Data API Key
api_key = os.getenv('API_KEY')


# Load CSV containing video links
csvFile = 'links.csv'  # Path to your CSV file
df = pd.read_csv(csvFile)

# List to store metadata for all videos
video_data = []

# Function to save captions to a text file
def save_captions_to_txt(video_id, captions_text):
    with open(f'dataset/captions/{video_id}_captions.txt', 'w', encoding='utf-8') as f:
        f.write(f'Video ID: {video_id}\n\n')
        f.write(captions_text)
        
# Function to extract video ID from YouTube short link
def getVideoId(url):
    import re
    pattern = r'(?:https?:\/\/)?(?:www\.)?youtube\.com\/shorts\/([A-Za-z0-9_-]{11})'
    match = re.match(pattern, url)
    return match.group(1) if match else None

# Function to fetch metadata using YouTube Data API
def fetchMetadata(videoId, apiKey):
    url = f'https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics,contentDetails&id={videoId}&key={apiKey}'
    response = requests.get(url)
    return response.json()

# Function to download video and captions using yt-dlp
def downloadVideoAndCaptions(videoUrl, videoId):
    # Create dataset folder if it doesn't exist
    output_dir = 'dataset'
    os.makedirs(output_dir, exist_ok=True)

    # Download video in MP4 format
    ydlOptsVideo = {
        'format': 'mp4',
        'outtmpl': f'{output_dir}/videos/{videoId}.mp4',  # Save the video as 'dataset/videoId.mp4'
    }
    with yt_dlp.YoutubeDL(ydlOptsVideo) as ydl:
        ydl.download([videoUrl])

    # Download captions if available
    ydlOptsSubtitles = {
        'writesubtitles': True,
        'subtitlesformat': 'vtt',
        'skip_download': True,
        'outtmpl': f'{output_dir}/captions_vtt/captions_vtt_{videoId}.vtt',  # Save the subtitles as 'dataset/videoId.vtt'
        'subtitleslangs': ['en'],  # Force download of English subtitles
    }
    with yt_dlp.YoutubeDL(ydlOptsSubtitles) as ydl:
        ydl.download([videoUrl])

# Function to get captions for a video using YouTubeTranscriptApi
def get_captions(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return transcript
    except Exception as e:
        print(f"Error retrieving captions for video {video_id}: {str(e)}")
        return None

# Iterate through each link in the CSV and process
for index, row in df.iterrows():
    print(f'short number - >  {index+1}')
    videoUrl = row['shorts_links']
    videoId = getVideoId(videoUrl)
    
    if videoId:
        # Fetch metadata
        metadata = fetchMetadata(videoId, apiKey)
        
        if 'items' in metadata and len(metadata['items']) > 0:
            # Extract relevant fields from metadata
            videoTitle = metadata['items'][0]['snippet']['title']
            videoDescription = metadata['items'][0]['snippet']['description']
            viewCount = metadata['items'][0]['statistics']['viewCount']
            likeCount = metadata['items'][0]['statistics'].get('likeCount', 0)
            commentCount = metadata['items'][0]['statistics'].get('commentCount', 0)
            captionsAvailable = metadata['items'][0]['contentDetails'].get('caption', 'false')

            # Fetch captions
            captions = get_captions(videoId)
            if captions:
                captions_text = ' '.join([item['text'] for item in captions])
            else:
                captions_text = 'No captions available'

            # Save captions to a text file
            save_captions_to_txt(videoId, captions_text)
            
            # Append the metadata to the list
            video_data.append({
                'Video URL': videoUrl,
                'Video ID': videoId,
                'Title': videoTitle,
                'Description': videoDescription,
                'View Count': viewCount,
                'Like Count': likeCount,
                'Comment Count': commentCount,
                'Captions Available': captionsAvailable,
                'Captions Text': captions_text
            })

            # Optionally download video and captions
            downloadVideoAndCaptions(videoUrl, videoId)
        else:
            print(f"Metadata not found for Video ID: {videoId}")

    else:
        print(f"Invalid URL: {videoUrl}")

# Create a DataFrame from the metadata list
video_df = pd.DataFrame(video_data)

# Save the DataFrame to a CSV file
output_csv_file = 'dataset/extracted_video_metadata.csv'
video_df.to_csv(output_csv_file, index=False)

print(f"Metadata saved to {output_csv_file}")
# Out:
# short number - >  1
# [youtube] Extracting URL: https://www.youtube.com/shorts/Cq1sQmFJBF0
# [youtube] Cq1sQmFJBF0: Downloading webpage
# [youtube] Cq1sQmFJBF0: Downloading ios player API JSON
# [youtube] Cq1sQmFJBF0: Downloading mweb player API JSON
# [youtube] Cq1sQmFJBF0: Downloading m3u8 information
# [info] Cq1sQmFJBF0: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/Cq1sQmFJBF0.mp4
# [download] 100% of    3.61MiB in 00:00:01 at 2.16MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/Cq1sQmFJBF0
# [youtube] Cq1sQmFJBF0: Downloading webpage
# [youtube] Cq1sQmFJBF0: Downloading ios player API JSON
# [youtube] Cq1sQmFJBF0: Downloading mweb player API JSON
# [youtube] Cq1sQmFJBF0: Downloading m3u8 information
# [info] Cq1sQmFJBF0: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  2
# [youtube] Extracting URL: https://www.youtube.com/shorts/6y-GZp_UUUo
# [youtube] 6y-GZp_UUUo: Downloading webpage
# [youtube] 6y-GZp_UUUo: Downloading ios player API JSON
# [youtube] 6y-GZp_UUUo: Downloading mweb player API JSON
# [youtube] 6y-GZp_UUUo: Downloading m3u8 information
# [info] 6y-GZp_UUUo: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/6y-GZp_UUUo.mp4
# [download] 100% of    4.15MiB in 00:00:01 at 2.46MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/6y-GZp_UUUo
# [youtube] 6y-GZp_UUUo: Downloading webpage
# [youtube] 6y-GZp_UUUo: Downloading ios player API JSON
# [youtube] 6y-GZp_UUUo: Downloading mweb player API JSON
# [youtube] 6y-GZp_UUUo: Downloading m3u8 information
# [info] 6y-GZp_UUUo: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  3
# [youtube] Extracting URL: https://www.youtube.com/shorts/xiJMjTnlxg4
# [youtube] xiJMjTnlxg4: Downloading webpage
# [youtube] xiJMjTnlxg4: Downloading ios player API JSON
# [youtube] xiJMjTnlxg4: Downloading mweb player API JSON
# [youtube] xiJMjTnlxg4: Downloading m3u8 information
# [info] xiJMjTnlxg4: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/xiJMjTnlxg4.mp4
# [download] 100% of    4.21MiB in 00:00:01 at 2.46MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/xiJMjTnlxg4
# [youtube] xiJMjTnlxg4: Downloading webpage
# [youtube] xiJMjTnlxg4: Downloading ios player API JSON
# [youtube] xiJMjTnlxg4: Downloading mweb player API JSON
# [youtube] xiJMjTnlxg4: Downloading m3u8 information
# [info] xiJMjTnlxg4: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  4
# [youtube] Extracting URL: https://www.youtube.com/shorts/SD8WJ7O1Q5M
# [youtube] SD8WJ7O1Q5M: Downloading webpage
# [youtube] SD8WJ7O1Q5M: Downloading ios player API JSON
# [youtube] SD8WJ7O1Q5M: Downloading mweb player API JSON
# [youtube] SD8WJ7O1Q5M: Downloading m3u8 information
# [info] SD8WJ7O1Q5M: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/SD8WJ7O1Q5M.mp4
# [download] 100% of    4.11MiB in 00:00:07 at 528.62KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/SD8WJ7O1Q5M
# [youtube] SD8WJ7O1Q5M: Downloading webpage
# [youtube] SD8WJ7O1Q5M: Downloading ios player API JSON
# [youtube] SD8WJ7O1Q5M: Downloading mweb player API JSON
# [youtube] SD8WJ7O1Q5M: Downloading m3u8 information
# [info] SD8WJ7O1Q5M: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  5
# [youtube] Extracting URL: https://www.youtube.com/shorts/x7M-FAV9-2Q
# [youtube] x7M-FAV9-2Q: Downloading webpage
# [youtube] x7M-FAV9-2Q: Downloading ios player API JSON
# [youtube] x7M-FAV9-2Q: Downloading mweb player API JSON
# [youtube] x7M-FAV9-2Q: Downloading m3u8 information
# [info] x7M-FAV9-2Q: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/x7M-FAV9-2Q.mp4
# [download] 100% of    4.00MiB in 00:00:02 at 1.42MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/x7M-FAV9-2Q
# [youtube] x7M-FAV9-2Q: Downloading webpage
# [youtube] x7M-FAV9-2Q: Downloading ios player API JSON
# [youtube] x7M-FAV9-2Q: Downloading mweb player API JSON
# [youtube] x7M-FAV9-2Q: Downloading m3u8 information
# [info] x7M-FAV9-2Q: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  6
# [youtube] Extracting URL: https://www.youtube.com/shorts/nifUnSk21-w
# [youtube] nifUnSk21-w: Downloading webpage
# [youtube] nifUnSk21-w: Downloading ios player API JSON
# [youtube] nifUnSk21-w: Downloading mweb player API JSON
# [youtube] nifUnSk21-w: Downloading m3u8 information
# [info] nifUnSk21-w: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/nifUnSk21-w.mp4
# [download] 100% of    4.15MiB in 00:00:02 at 2.06MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/nifUnSk21-w
# [youtube] nifUnSk21-w: Downloading webpage
# [youtube] nifUnSk21-w: Downloading ios player API JSON
# [youtube] nifUnSk21-w: Downloading mweb player API JSON
# [youtube] nifUnSk21-w: Downloading m3u8 information
# [info] nifUnSk21-w: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  7
# [youtube] Extracting URL: https://www.youtube.com/shorts/qbu8hN4Qv00
# [youtube] qbu8hN4Qv00: Downloading webpage
# [youtube] qbu8hN4Qv00: Downloading ios player API JSON
# [youtube] qbu8hN4Qv00: Downloading mweb player API JSON
# [youtube] qbu8hN4Qv00: Downloading m3u8 information
# [info] qbu8hN4Qv00: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/qbu8hN4Qv00.mp4
# [download] 100% of    4.24MiB in 00:00:04 at 1.04MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/qbu8hN4Qv00
# [youtube] qbu8hN4Qv00: Downloading webpage
# [youtube] qbu8hN4Qv00: Downloading ios player API JSON
# [youtube] qbu8hN4Qv00: Downloading mweb player API JSON
# [youtube] qbu8hN4Qv00: Downloading m3u8 information
# [info] qbu8hN4Qv00: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >
Downloading 1 format(s): 18
# [download] Destination: dataset/videos/GQkkHtBD1BM.mp4
# [download] 100% of    4.38MiB in 00:00:03 at 1.12MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/GQkkHtBD1BM
# [youtube] GQkkHtBD1BM: Downloading webpage
# [youtube] GQkkHtBD1BM: Downloading ios player API JSON
# [youtube] GQkkHtBD1BM: Downloading mweb player API JSON
# [youtube] GQkkHtBD1BM: Downloading m3u8 information
# [info] GQkkHtBD1BM: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  17
# [youtube] Extracting URL: https://www.youtube.com/shorts/XKGJTMJVRBs
# [youtube] XKGJTMJVRBs: Downloading webpage
# [youtube] XKGJTMJVRBs: Downloading ios player API JSON
# [youtube] XKGJTMJVRBs: Downloading mweb player API JSON
# [youtube] XKGJTMJVRBs: Downloading m3u8 information
# [info] XKGJTMJVRBs: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/XKGJTMJVRBs.mp4
# [download] 100% of    4.07MiB in 00:00:03 at 1.06MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/XKGJTMJVRBs
# [youtube] XKGJTMJVRBs: Downloading webpage
# [youtube] XKGJTMJVRBs: Downloading ios player API JSON
# [youtube] XKGJTMJVRBs: Downloading mweb player API JSON
# [youtube] XKGJTMJVRBs: Downloading m3u8 information
# [info] XKGJTMJVRBs: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  18
# [youtube] Extracting URL: https://www.youtube.com/shorts/cpUH4FIamYg
# [youtube] cpUH4FIamYg: Downloading webpage
# [youtube] cpUH4FIamYg: Downloading ios player API JSON
# [youtube] cpUH4FIamYg: Downloading mweb player API JSON
# [youtube] cpUH4FIamYg: Downloading m3u8 information
# [info] cpUH4FIamYg: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/cpUH4FIamYg.mp4
# [download] 100% of    4.25MiB in 00:00:03 at 1.24MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/cpUH4FIamYg
# [youtube] cpUH4FIamYg: Downloading webpage
# [youtube] cpUH4FIamYg: Downloading ios player API JSON
# [youtube] cpUH4FIamYg: Downloading mweb player API JSON
# [youtube] cpUH4FIamYg: Downloading m3u8 information
# [info] cpUH4FIamYg: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  19
# [youtube] Extracting URL: https://www.youtube.com/shorts/YWTgoUqm3tY
# [youtube] YWTgoUqm3tY: Downloading webpage
# [youtube] YWTgoUqm3tY: Downloading ios player API JSON
# [youtube] YWTgoUqm3tY: Downloading mweb player API JSON
# [youtube] YWTgoUqm3tY: Downloading m3u8 information
# [info] YWTgoUqm3tY: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/YWTgoUqm3tY.mp4
# [download] 100% of    4.24MiB in 00:00:07 at 609.84KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/YWTgoUqm3tY
# [youtube] YWTgoUqm3tY: Downloading webpage
# [youtube] YWTgoUqm3tY: Downloading ios player API JSON
# [youtube] YWTgoUqm3tY: Downloading mweb player API JSON
# [youtube] YWTgoUqm3tY: Downloading m3u8 information
# [info] YWTgoUqm3tY: Downloading 1 format(s): 616+251-2
# [info] There are no subtitles for the requested languages
# short number - >  20
# [youtube] Extracting URL: https://www.youtube.com/shorts/roheTIg6pmk
# [youtube] roheTIg6pmk: Downloading webpage
# [youtube] roheTIg6pmk: Downloading ios player API JSON
# [youtube] roheTIg6pmk: Downloading mweb player API JSON
# [youtube] roheTIg6pmk: Downloading m3u8 information
# [info] roheTIg6pmk: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/roheTIg6pmk.mp4
# [download] 100% of    4.26MiB in 00:00:06 at 681.62KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts
Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  28
# [youtube] Extracting URL: https://www.youtube.com/shorts/IbhnTf-EqRY
# [youtube] IbhnTf-EqRY: Downloading webpage
# [youtube] IbhnTf-EqRY: Downloading ios player API JSON
# [youtube] IbhnTf-EqRY: Downloading mweb player API JSON
# [youtube] IbhnTf-EqRY: Downloading m3u8 information
# [info] IbhnTf-EqRY: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/IbhnTf-EqRY.mp4
# [download] 100% of    3.84MiB in 00:00:04 at 819.41KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/IbhnTf-EqRY
# [youtube] IbhnTf-EqRY: Downloading webpage
# [youtube] IbhnTf-EqRY: Downloading ios player API JSON
# [youtube] IbhnTf-EqRY: Downloading mweb player API JSON
# [youtube] IbhnTf-EqRY: Downloading m3u8 information
# [info] IbhnTf-EqRY: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  29
# [youtube] Extracting URL: https://www.youtube.com/shorts/bDuzEwInD7U
# [youtube] bDuzEwInD7U: Downloading webpage
# [youtube] bDuzEwInD7U: Downloading ios player API JSON
# [youtube] bDuzEwInD7U: Downloading mweb player API JSON
# [youtube] bDuzEwInD7U: Downloading m3u8 information
# [info] bDuzEwInD7U: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/bDuzEwInD7U.mp4
# [download] 100% of    2.69MiB in 00:00:02 at 1.12MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/bDuzEwInD7U
# [youtube] bDuzEwInD7U: Downloading webpage
# [youtube] bDuzEwInD7U: Downloading ios player API JSON
# [youtube] bDuzEwInD7U: Downloading mweb player API JSON
# [youtube] bDuzEwInD7U: Downloading m3u8 information
# [info] bDuzEwInD7U: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  30
# [youtube] Extracting URL: https://www.youtube.com/shorts/ltpbEQA8Fwc
# [youtube] ltpbEQA8Fwc: Downloading webpage
# [youtube] ltpbEQA8Fwc: Downloading ios player API JSON
# [youtube] ltpbEQA8Fwc: Downloading mweb player API JSON
# [youtube] ltpbEQA8Fwc: Downloading m3u8 information
# [info] ltpbEQA8Fwc: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/ltpbEQA8Fwc.mp4
# [download] 100% of    4.20MiB in 00:00:04 at 880.83KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/ltpbEQA8Fwc
# [youtube] ltpbEQA8Fwc: Downloading webpage
# [youtube] ltpbEQA8Fwc: Downloading ios player API JSON
# [youtube] ltpbEQA8Fwc: Downloading mweb player API JSON
# [youtube] ltpbEQA8Fwc: Downloading m3u8 information
# [info] ltpbEQA8Fwc: Downloading 1 format(s): 616+251-2
# [info] There are no subtitles for the requested languages
# short number - >  31
# [youtube] Extracting URL: https://www.youtube.com/shorts/1EvNX2_4zfE
# [youtube] 1EvNX2_4zfE: Downloading webpage
# [youtube] 1EvNX2_4zfE: Downloading ios player API JSON
# [youtube] 1EvNX2_4zfE: Downloading mweb player API JSON
# [youtube] 1EvNX2_4zfE: Downloading m3u8 information
# [info] 1EvNX2_4zfE: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/1EvNX2_4zfE.mp4
# [download] 100% of    3.45MiB in 00:00:04 at 801.12KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/1EvNX2_4zfE
# [youtube] 1EvNX2_4zfE: Downloading webpage
# [youtube] 1EvNX2_4zfE: Downloading ios player API JSON
# [youtube] 1EvNX2_4zfE: Downloading mweb player API JSON
# [youtube] 1EvNX2_4zfE: Downloading m3u8 information
# [info] 1EvNX2_4zfE: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# short number - >  32
# [youtube] Extracting URL: https://www.youtube.com/shorts/yqOuowxeOOw
# [youtube] yqOuowxeOOw: Downloading webpage
# [youtube] yqOuowxeOOw: Downloading ios player API JSON
# [youtube] yqOuowxeOOw: Downloading mweb player API JSON
# [youtube] yqOuowxeOOw: Downloading m3u8 information
# [info] yqOuowxeOOw: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/yqOuowxeOOw.mp4
# [download] 100% of    4.21MiB in 00:00:02 at 2.10MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/yqOuowxeOOw
# [youtube] yqOuowxeOOw: Downloading webpage
# [youtube] yqOuowxeOOw: Downloading ios player API JSON
# [youtube] yqOuowxeOOw: Downloading mweb player API JSON
# [youtube] yqOuowxeOOw: Downloading m3u8 information
# [info] yqOuowxeOOw: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  33
# [youtube] Extracting URL: https://www.youtube.com/shorts/zsxviDibcUg
# [youtube] zsxviDibcUg: Downloading webpage
# [youtube] zsxviDibcUg: Downloading ios player API JSON
# [youtube] zsxviDibcUg: Downloading mweb player API JSON
# [youtube] zsxviDibcUg: Downloading m3u8 information
# [info] zsxviDibcUg: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/zsxviDibcUg.mp4
# [download] 100% of    4.23MiB in 00:00:03 at 1.25MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/zsxviDibcUg
# [youtube] zsxviDibcUg: Downloading webpage
# [youtube] zsxviDibcUg: Downloading ios player API JSON
# [youtube] zsxviDibcUg: Downloading mweb player API JSON
# [youtube] zsxviDibcUg: Downloading m3u8 information
# [info] zsxviDibcUg: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  34
# [youtube] Extracting URL: https://www.youtube.com/shorts/VlIeANvowso
# [youtube] VlIeANvowso: Downloading webpage
# [youtube] VlIeANvowso: Downloading ios player API JSON
# [youtube] VlIeANvowso: Downloading mweb player API JSON
# [youtube] VlIeANvowso: Downloading m3u8 information
# [info] VlIeANvowso: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/VlIeANvowso.mp4
# [download] 100% of    4.23MiB in 00:00:03 at 1.20MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/VlIeANvowso
# [youtube] VlIeANvowso: Downloading webpage
# [youtube] VlIeANvowso: Downloading ios player API JSON
# [youtube] VlIeANvowso: Downloading mweb player API JSON
# [youtube] VlIeANvowso: Downloading m3u8 information
# [info] VlIeANvowso: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  35
# [youtube] Extracting URL: https://www.youtube.com/shorts/pHhpXrIOwsY
# [youtube] pHhpXrIOwsY: Downloading webpage
# [youtube] pHhpXrIOwsY: Downloading ios player API JSON
# [youtube] pHhpXrIOwsY: Downloading mweb player API JSON
# [youtube] pHhpXrIOwsY: Downloading m3u8 information
# [info] pHhpXrIOwsY: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/pHhpXrIOwsY.mp4
# [download] 100% of    4.24MiB in 00:00:02 at 1.77MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/pHhpXrIOwsY
# [youtube] pHhpXrIOwsY: Downloading webpage
# [youtube] pHhpXrIOwsY: Downloading ios player API JSON
# [youtube] pHhpXrIOwsY: Downloading mweb player API JSON
# [youtube] pHhpXrIOwsY: Downloading m3u8 information
# [info] pHhpXrIOwsY: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  36
# [youtube] Extracting URL: https://www.youtube.com/shorts/bDtuVp1ywTo
# [youtube] bDtuVp1ywTo: Downloading webpage
# [youtube] bDtuVp1ywTo: Downloading ios player API JSON
# [youtube] bDtuVp1ywTo: Downloading mweb player API JSON
# [youtube] bDtuVp1ywTo: Downloading m3u8 information
# [info] bDtuVp1ywTo: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/bDtuVp1ywTo.mp4
# [download] 100% of    2.71MiB in 00:00:03 at 827.95KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/bDtuVp1ywTo
# [youtube] bDtuVp1ywTo: Downloading webpage
# [youtube] bDtuVp1ywTo: Downloading ios player API JSON
# [youtube] bDtuVp1ywTo: Downloading mweb player API JSON
# [youtube] bDtuVp1ywTo: Downloading m3u8 information
# [info] bDtuVp1ywTo: Downloading 1 format(s): 313+251
# [info] There are no subtitles for the requested languages
# short number - >  37
# [youtube] Extracting URL: https://www.youtube.com/shorts/wpBu5ej7m8g
# [youtube] wpBu5ej7m8g: Downloading webpage
# [youtube] wpBu5ej7m8g: Downloading ios player API JSON
# [youtube] wpBu5ej7m8g: Downloading mweb player API JSON
# [youtube] wpBu5ej7m8g: Downloading m3u8 information
# [info] wpBu5ej7m8g: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/wpBu5ej7m8g.mp4
# [download] 100% of    4.23MiB in 00:00:04 at 917.31KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/wpBu5ej7m8g
# [youtube] wpBu5ej7m8g: Downloading webpage
# [youtube] wpBu5ej7m8g: Downloading ios player API JSON
# [youtube] wpBu5ej7m8g: Downloading mweb player API JSON
# [youtube] wpBu5ej7m8g: Downloading m3u8 information
# [info] wpBu5ej7m8g: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  38
# [youtube] Extracting URL: https://www.youtube.com/shorts/FNnK1J-BdiM
# [youtube] FNnK1J-BdiM: Downloading webpage
# [youtube] FNnK1J-BdiM: Downloading ios player API JSON
# [youtube] FNnK1J-BdiM: Downloading mweb player API JSON
# [youtube] FNnK1J-BdiM: Downloading m3u8 information
# [info] FNnK1J-BdiM: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/FNnK1J-BdiM.mp4
# [download] 100% of    3.93MiB in 00:00:02 at 1.44MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/FNnK1J-BdiM
# [youtube] FNnK1J-BdiM: Downloading webpage
# [youtube] FNnK1J-BdiM: Downloading ios player API JSON
# [youtube] FNnK1J-BdiM: Downloading mweb player API JSON
# [youtube] FNnK1J-BdiM: Downloading m3u8 information
# [info] FNnK1J-BdiM: Downloading 1 format(s): 313+251-3
# [info] There are no subtitles for the requested languages
# short number - >  39
# [youtube] Extracting URL: https://www.youtube.com/shorts/tciqW8VKfOU
# [youtube] tciqW8VKfOU: Downloading webpage
# [youtube] tciqW8VKfOU: Downloading ios player API JSON
# [youtube] tciqW8VKfOU: Downloading mweb player API JSON
# [youtube] tciqW8VKfOU: Downloading m3u8 information
# [info] tciqW8VKfOU: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/tciqW8VKfOU.mp4
# [download] 100% of    2.50MiB in 00:00:03 at 765.83KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/tciqW8VKfOU
# [youtube] tciqW8VKfOU: Downloading webpage
# [youtube] tciqW8VKfOU: Downloading ios player API JSON
# [youtube] tciqW8VKfOU: Downloading mweb player API JSON
# [youtube] tciqW8VKfOU: Downloading m3u8 information
# [info] tciqW8VKfOU: Downloading 1 format(s): 313+251
# [info] There are no subtitles for the requested languages
# short number - >  40
# [youtube] Extracting URL: https://www.youtube.com/shorts/UXB9bnuyZb4
# [youtube] UXB9bnuyZb4: Downloading webpage
# [youtube] UXB9bnuyZb4: Downloading ios player API JSON
# [youtube] UXB9bnuyZb4: Downloading mweb player API JSON
# [youtube] UXB9bnuyZb4: Downloading m3u8 information
# [info] UXB9bnuyZb4: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/UXB9bnuyZb4.mp4
# [download] 100% of    4.28MiB in 00:00:04 at 919.24KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/UXB9bnuyZb4
# [youtube] UXB9bnuyZb4: Downloading webpage
# [youtube] UXB9bnuyZb4: Downloading ios player API JSON
# [youtube] UXB9bnuyZb4: Downloading mweb player API JSON
# [youtube] UXB9bnuyZb4: Downloading m3u8 information
# [info] UXB9bnuyZb4: Downloading 1 format(s): 313+251-2
# [info] There are no subtitles for the requested languages
# short number - >  41
# [youtube] Extracting URL: https://www.youtube.com/shorts/DO1PJYAQj0c
# [youtube] DO1PJYAQj0c: Downloading webpage
# [youtube] DO1PJYAQj0c: Downloading ios player API JSON
# [youtube] DO1PJYAQj0c: Downloading mweb player API JSON
# [youtube] DO1PJYAQj0c: Downloading m3u8 information
# [info] DO1PJYAQj0c: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/DO1PJYAQj0c.mp4
# [download] 100% of    4.13MiB in 00:00:03 at 1.13MiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/DO1PJYAQj0c
# [youtube] DO1PJYAQj0c: Downloading webpage
# [youtube] DO1PJYAQj0c: Downloading ios player API JSON
# [youtube] DO1PJYAQj0c: Downloading mweb player API JSON
# [youtube] DO1PJYAQj0c: Downloading m3u8 information
# [info] DO1PJYAQj0c: Downloading 1 format(s): 313+251-1
# [info] There are no subtitles for the requested languages
# short number - >  42
# [youtube] Extracting URL: https://www.youtube.com/shorts/REVveXIMk7c
# [youtube] REVveXIMk7c: Downloading webpage
# [youtube] REVveXIMk7c: Downloading ios player API JSON
# [youtube] REVveXIMk7c: Downloading mweb player API JSON
# [youtube] REVveXIMk7c: Downloading m3u8 information
# [info] REVveXIMk7c: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/REVveXIMk7c.mp4
# [download] 100% of    4.32MiB in 00:00:04 at 947.54KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/REVveXIMk7c
# [youtube] REVveXIMk7c: Downloading webpage
# [youtube] REVveXIMk7c: Downloading ios player API JSON
# [youtube] REVveXIMk7c: Downloading mweb player API JSON
# [youtube] REVveXIMk7c: Downloading m3u8 information
# [info] REVveXIMk7c: Downloading 1 format(s): 313+251-1
# [info] There are no subtitles for the requested languages
# short number - >  43
# [youtube] Extracting URL: https://www.youtube.com/shorts/K6gtEGnbR6I
# [youtube] K6gtEGnbR6I: Downloading webpage
# [youtube] K6gtEGnbR6I: Downloading ios player API JSON
# [youtube] K6gtEGnbR6I: Downloading mweb player API JSON
# [youtube] K6gtEGnbR6I: Downloading m3u8 information
# [info] K6gtEGnbR6I: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/K6gtEGnbR6I.mp4
# [download] 100% of    4.17MiB in 00:00:04 at 999.51KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts
Downloading 1 format(s): 18
# [download] Destination: dataset/videos/a01edYZIfjc.mp4
# [download] 100% of    4.27MiB in 00:00:05 at 771.13KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/a01edYZIfjc
# [youtube] a01edYZIfjc: Downloading webpage
# [youtube] a01edYZIfjc: Downloading ios player API JSON
# [youtube] a01edYZIfjc: Downloading mweb player API JSON
# [youtube] a01edYZIfjc: Downloading m3u8 information
# [info] a01edYZIfjc: Downloading 1 format(s): 313+251-1
# [info] There are no subtitles for the requested languages
# short number - >  48
# [youtube] Extracting URL: https://www.youtube.com/shorts/bi1XS6s1rBY
# [youtube] bi1XS6s1rBY: Downloading webpage
# [youtube] bi1XS6s1rBY: Downloading ios player API JSON
# [youtube] bi1XS6s1rBY: Downloading mweb player API JSON
# [youtube] bi1XS6s1rBY: Downloading m3u8 information
# [info] bi1XS6s1rBY: Downloading 1 format(s): 18
# [download] Destination: dataset/videos/bi1XS6s1rBY.mp4
# [download] 100% of    2.78MiB in 00:00:03 at 884.81KiB/s
# [youtube] Extracting URL: https://www.youtube.com/shorts/bi1XS6s1rBY
# [youtube] bi1XS6s1rBY: Downloading webpage
# [youtube] bi1XS6s1rBY: Downloading ios player API JSON
# [youtube] bi1XS6s1rBY: Downloading mweb player API JSON
# [youtube] bi1XS6s1rBY: Downloading m3u8 information
# [info] bi1XS6s1rBY: Downloading 1 format(s): 313+251
# [info] There are no subtitles for the requested languages
# Metadata saved to dataset/extracted_video_metadata.csv

# %% [markdown]
# # get shorts links

# %%
#mkbhd has these amounts of shorts
5*14
# Out:
# 70

# %% [markdown]
# # get all the top shorts of mkbhd

# %% [markdown]
# ## get the html of short page first
#
# (beware : commiting this file will expose the api key)

# %%
import requests

# URL of the YouTube Shorts page for MKBHD
url = 'https://www.youtube.com/@mkbhd/shorts'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Save the response content to an HTML file
    with open('mkbhd_shorts_page.html', 'w', encoding='utf-8') as file:
        file.write(response.text)
    print("Webpage saved as mkbhd_shorts_page.html")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

# %% [markdown]
# ## parse the short page

# %%
import re
import csv
# Read the content of the HTML file
html_file = 'mkbhd_shorts_page.html'  # Path to your HTML file

with open(html_file, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Regular expression to match the videoId pattern
video_id_pattern = r'"videoId":"([A-Za-z0-9_-]{11})"'

# Find all matches for the videoId in the HTML content
video_ids = re.findall(video_id_pattern, html_content)

# Use an ordered approach to remove duplicates while preserving the order
unique_video_ids = []
seen = set()

for video_id in video_ids:
    if video_id not in seen:
        unique_video_ids.append(video_id)
        seen.add(video_id)

# Print all unique extracted video IDs
print("Extracted unique video IDs (preserving order):")
for video_id in unique_video_ids:
    print(video_id)

# Save the unique video IDs as YouTube Shorts links in a CSV file
csv_filename = 'links.csv'

with open(csv_filename, 'w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    # Write the header
    csv_writer.writerow(['shorts_links'])
    # Write each video link
    for video_id in unique_video_ids:
        csv_writer.writerow([f'https://www.youtube.com/shorts/{video_id}'])

print(f"Unique video links saved to {csv_filename}")
